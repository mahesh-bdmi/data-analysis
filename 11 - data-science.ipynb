# %%
from urllib.request import urlretrieve
urlretrieve('https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv','pokemon.csv')
# Out:
# ('pokemon.csv', <http.client.HTTPMessage at 0x136a276f4f0>)

# %%
import pandas as pd
pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon[pokemon['Type 1']=='Fire']['Name']
# Out:
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 42                        Vulpix
# 43                     Ninetales
# 63                     Growlithe
# 64                      Arcanine
# 83                        Ponyta
# 84                      Rapidash
# 135                       Magmar
# 147                      Flareon
# 158                      Moltres
# 169                    Cyndaquil
# 170                      Quilava
# 171                   Typhlosion
# 236                       Slugma
# 237                     Magcargo
# 259                        Magby
# 263                        Entei
# 270                        Ho-oh
# 276                      Torchic
# 277                    Combusken
# 278                     Blaziken
# 279        BlazikenMega Blaziken
# 352                        Numel
# 353                     Camerupt
# ...

# %%
pokemon.sort_values(['Attack', 'Defense'], ascending=[0,0])
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon['Total'] = pokemon.iloc[:,4:10].sum(axis=1)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
cols = list(pokemon.columns)
pokemon = pokemon[cols[0:4]+[cols[-1]]+cols[4:12]] #rearranging the columns

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.to_csv('pokemonv2.csv',index=False)

# %%
pokemon.loc[(pokemon['Type 1'] == 'Fire') & (pokemon['HP'] > 100)] #filter by condition
# Out:
#        #                     Name Type 1    Type 2  Total   HP  Attack  \
# 263  244                    Entei   Fire       NaN    580  115     115
# 270  250                    Ho-oh   Fire    Flying    680  106     130
# 559  500                   Emboar   Fire  Fighting    528  110     123
# 615  555  DarmanitanStandard Mode   Fire       NaN    480  105     140
# 616  555       DarmanitanZen Mode   Fire   Psychic    540  105      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 263       85       90       75    100           2       True
# 270       90      110      154     90           2       True
# 559       65      100       65     65           5      False
# 615       55       30       55     95           5      False
# 616      105      140      105     55           5      False

# %%
pokemon.loc[pokemon['Name'].str.contains('Mega')] # Use ~ to select the inverse

# %%
pokemon.loc[pokemon['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

pokemon.loc[pokemon['Name'].str.contains('^pi[a-z]*',regex=True,flags=re.I)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
pokemon.loc[pokemon['Type 1'] == 'Fire','Type 1'] = 'Flame' #conditionally change values
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander  Flame       NaN    309   39      52
# 5      5                 Charmeleon  Flame       NaN    405   58      64
# 6      6                  Charizard  Flame    Flying    534   78      84
# 7      6  CharizardMega Charizard X  Flame    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y  Flame    Flying    634   78     104
# 42    37                     Vulpix  Flame       NaN    299   38      41
# 43    38                  Ninetales  Flame       NaN    505   73      76
# 63    58                  Growlithe  Flame       NaN    350   55      70
# 64    59                   Arcanine  Flame       NaN    555   90     110
# 83    77                     Ponyta  Flame       NaN    410   50      85
# 84    78                   Rapidash  Flame       NaN    500   65     100
# 135  126                     Magmar  Flame       NaN    495   65      95
# ...
